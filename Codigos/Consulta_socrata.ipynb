# %%
# Paso 1: Descargar los datos con requests y leerlos en pandas
import requests
import pandas as pd
from io import StringIO

url_secop = "https://www.datos.gov.co/resource/rpmr-utcd.csv?$limit=100000"
url_men = "https://www.datos.gov.co/resource/nudc-7mev.csv?$limit=10000"

# Descargar contenido
response_secop = requests.get(url_secop)
response_men = requests.get(url_men)

# Convertir contenido a pandas usando StringIO
df_secop_pd = pd.read_csv(StringIO(response_secop.text))
df_men_pd = pd.read_csv(StringIO(response_men.text))

# Mostrar en Databricks
display(df_secop_pd)
display(df_men_pd)
# Out:
#       nivel_entidad  codigo_entidad_en_secop  \
# 0       TERRITORIAL                213001013
# 1       TERRITORIAL                213001013
# 2       TERRITORIAL                213001013
# 3       TERRITORIAL                213001013
# 4       TERRITORIAL                213001013
# ...             ...                      ...
# 99995   TERRITORIAL                213300017
# 99996   TERRITORIAL                213300017
# 99997   TERRITORIAL                213300017
# 99998   TERRITORIAL                213300017
# 99999   TERRITORIAL                213300017
#
#                                     nombre_de_la_entidad nit_de_la_entidad  \
# 0      BOLÍVAR - INSTITUCIÓN UNIVERSITARIA BELLAS ART...         890480308
# 1      BOLÍVAR - INSTITUCIÓN UNIVERSITARIA BELLAS ART...         890480308
# 2      BOLÍVAR - INSTITUCIÓN UNIVERSITARIA BELLAS ART...         890480308
# 3      BOLÍVAR - INSTITUCIÓN UNIVERSITARIA BELLAS ART...         890480308
# 4      BOLÍVAR - INSTITUCIÓN UNIVERSITARIA BELLAS ART...         890480308
# ...                                                  ...               ...
# 99995          BOLÍVAR - E.S.E. HOSPITAL HATILLO DE LOBA         806013761
# 99996          BOLÍVAR - E.S.E. HOSPITAL HATILLO DE LOBA         806013761
# 99997          BOLÍVAR - E.S.E. HOSPITAL HATILLO DE LOBA         806013761
# 99998          BOLÍVAR - E.S.E. HOSPITAL HATILLO DE LOBA         806013761
# 99999          BOLÍVAR - E.S.E. HOSPITAL HATILLO DE LOBA         806013761
#
#       departamento_entidad municipio_entidad estado_del_proceso  \
# 0                  Bolívar         Cartagena          Liquidado
# 1                  Bolívar         Cartagena          Liquidado
# 2                  Bolívar         Cartagena          Liquidado
# 3                  Bolívar         Cartagena          Liquidado
# 4                  Bolívar         Cartagena          Liquidado
# ...                    ...               ...                ...
# 99995              Bolívar   Hatillo de Loba          Celebrado
# 99996              Bolívar   Hatillo de Loba          Celebrado
# 99997              Bolívar   Hatillo de Loba          Celebrado
# 99998              Bolívar   Hatillo de Loba          Celebrado
# 99999              Bolívar   Hatillo de Loba          Celebrado
#
#                                modalidad_de_contrataci_n  \
# 0      Selección Abreviada de Menor Cuantía (Ley 1150...
# 1      Selección Abreviada de Menor Cuantía (Ley 1150...
# 2      Selección Abreviada de Menor Cuantía (Ley 1150...
# 3      Selección Abreviada de Menor Cuantía (Ley 1150...
# 4      Selección Abreviada de Menor Cuantía (Ley 1150...
# ...                                                  ...
# 99995                                   Régimen Especial
# 99996                                   Régimen Especial
# 99997                                   Régimen Especial
# 99998                                   Régimen Especial
# 99999                                   Régimen Especial
#
#                                       objeto_a_contratar  \
# 0      SUMINISTRO DE ELEMENTOS DE ASEO Y CAFETERIA PA...
# 1      SUMINISTRO DE ELEMENTOS DE ASEO Y CAFETERIA PA...
# 2      SUMINISTRO DE ELEMENTOS DE PAPELERIA Y UTILES ...
# 3      SUMINISTRO DE ELEMENTOS IMPLEMENTOS DE FERRETE...
# 4      SUMINISTRO DE ELEMENTOS IMPLEMENTOS DE FERRETE...
# ...                                                  ...
# 99995  CONTRATO DE PRESTACION DE SERVICIOS PROFESIONA...
# 99996  CONTRATO DE PRESTACION DE SERVICIOS PROFESIONA...
# 99997  CONTRATO DE PRESTACION DE SERVICIOS PROFESIONA...
# 99998  CONTRATO DE PRESTACION DE SERVICIOS PROFESIONA...
# 99999  CONTRATO DE PRESTACION DE SERVICIS DE APOYO A ...
#
#                                       objeto_del_proceso  ...  \
# 0      SUMINISTRO DE ELEMENTOS DE ASEO Y CAFETERiA PA...  ...
# 1      SUMINISTRO DE ELEMENTOS DE ASEO Y CAFETERiA PA...  ...
# 2      SUMINISTRO DE PAPELERiA uTILES DE OFICINA TINT...  ...
# 3      SUMINISTRO DE ELEMENTOS IMPLEMENTOS DE FERRETE...  ...
# 4      SUMINISTRO DE ELEMENTOS IMPLEMENTOS DE FERRETE...  ...
# ...                                                  ...  ...
# 99995  CONTRATO DE PRESTACION DE SERVICIOS PROFESIONA...  ...
# 99996  CONTRATO DE PRESTACIoN DE SERVICIOS PROFESIONA...  ...
# 99997  CONTRATO DE PRESTACION DE SERVICIOS PROFESIONA...  ...
# 99998  CONTRATO DE PRESTACION DE SERVICIOS PROFESIONA...  ...
# 99999  CONTRATO DE PRESTACION DE SERVICIS DE APOYO A ...  ...
#
#         fecha_inicio_ejecuci_n      fecha_fin_ejecuci_n numero_del_contrato  \
# 0      2020-03-05T00:00:00.000  2021-01-05T00:00:00.000      20-11-10402783
# 1      2021-04-06T00:00:00.000  2022-01-06T00:00:00.000      21-11-11763552
# 2      2015-03-16T00:00:00.000  2015-12-16T00:00:00.000       15-11-3451091
# 3      2019-03-28T00:00:00.000  2019-12-28T00:00:00.000       19-11-9099820
# 4      2020-02-18T00:00:00.000  2020-12-26T00:00:00.000      20-11-10327552
# ...                        ...                      ...                 ...
# 99995  2020-04-16T00:00:00.000  2020-06-30T00:00:00.000       21-4-11974922
# 99996  2018-02-01T00:00:00.000  2018-05-01T00:00:00.000        18-4-8471809
# 99997  2021-01-08T00:00:00.000  2021-02-08T00:00:00.000       22-4-13040003
# 99998  2023-06-26T00:00:00.000  2023-12-31T00:00:00.000       24-4-14002795
# 99999  2023-01-16T00:00:00.000  2023-04-02T00:00:00.000       23-4-13602768
#
#          numero_de_proceso valor_contrato  \
# 0      UNIBAC-PSA-003-2020       97628566
# 1       UNBAC-PSA-003-2021       99937382
# 2       UNIBAC 007 DE 2015      140000000
# 3      UNIBAC-PSA-005-2019       50003551
# 4      UNIBAC-PSA-002-2020       60000000
# ...                    ...            ...
# 99995         014-16042020        8750000
# 99996         006 del 2018        6600000
# 99997          20210108-01       11000000
# 99998         C20230626-12        9000000
# 99999         C20230116-17        3344000
#
#                          nom_raz_social_contratista  \
# 0      DISTRIBUIDORA DE PRODUCTOS Y SERVICIOS S.A.S
# 1                                        DISPRO SAS
# 2                                       DISPRO LTDA
# 3                 ALMACEN Y FERRETERIA PEMEL S.A.S.
# 4                 ALMACEN Y FERRETERIA PEMEL S.A.S.
# ...                                             ...
# 99995                  FRANCISCO JAVIER PARRA ACUNA
# 99996                  HELEN PAOLA PALENCIA CENTENO
# 99997                  LUIS FERNANDO MARTINEZ ORTIZ
# 99998                     OLGA JANETH LOPEZ AGUDELO
# 99999                      WILMER SALAZAR BENAVIDES
#
#                                             url_contrato  origen  \
# 0      https://www.contratos.gov.co/consultas/detalle...  SECOPI
# 1      https://www.contratos.gov.co/consultas/detalle...  SECOPI
# 2      https://www.contratos.gov.co/consultas/detalle...  SECOPI
# 3      https://www.contratos.gov.co/consultas/detalle...  SECOPI
# 4      https://www.contratos.gov.co/consultas/detalle...  SECOPI
# ...                                                  ...     ...
# 99995  https://www.contratos.gov.co/consultas/detalle...  SECOPI
# 99996  https://www.contratos.gov.co/consultas/detalle...  SECOPI
# 99997  https://www.contratos.gov.co/consultas/detalle...  SECOPI
# 99998  https://www.contratos.gov.co/consultas/detalle...  SECOPI
# 99999  https://www.contratos.gov.co/consultas/detalle...  SECOPI
#
#       tipo_documento_proveedor documento_proveedor
# 0      Nit de Persona Jurídica           806006084
# 1      Nit de Persona Jurídica           806006084
# 2      Nit de Persona Jurídica         8/060060841
# 3      Nit de Persona Jurídica           900457218
# 4      Nit de Persona Jurídica           900457218
# ...                        ...                 ...
# 99995     Cédula de Ciudadanía             9265390
# 99996     Cédula de Ciudadanía          1047474205
# 99997     Cédula de Ciudadanía          1216972644
# 99998     Cédula de Ciudadanía            31415977
# 99999     Cédula de Ciudadanía            85167226
#
# [100000 rows x 22 columns]
#        a_o  c_digo_municipio               municipio  c_digo_departamento  \
# 0     2023              5004                Abriaquí                    5
# 1     2023             95025              El Retorno                   95
# 2     2023             95200              Miraflores                   95
# 3     2023             97001                    Mitú                   97
# 4     2023             97161                  Caruru                   97
# ...    ...               ...                     ...                  ...
# 9995  2015              5664               San Pedro                    5
# 9996  2015              5660                San Luis                    5
# 9997  2015              5659       San Juan de Urabá                    5
# 9998  2015              5658  San José de la Montaña                    5
# 9999  2015              5656            San Jerónimo                    5
#
#      departamento  c_digo_etc              etc poblaci_n_5_16  \
# 0       Antioquia      3758.0  Antioquia (ETC)            503
# 1        Guaviare      3830.0   Guaviare (ETC)           4438
# 2        Guaviare      3830.0   Guaviare (ETC)           2014
# 3          Vaupés      3831.0     Vaupés (ETC)          10986
# 4          Vaupés      3831.0     Vaupés (ETC)           1228
# ...           ...         ...              ...            ...
# 9995    Antioquia      3758.0  Antioquia (ETC)           6173
# 9996    Antioquia      3758.0  Antioquia (ETC)           2447
# 9997    Antioquia      3758.0  Antioquia (ETC)           7050
# 9998    Antioquia      3758.0  Antioquia (ETC)            906
# 9999    Antioquia      3758.0  Antioquia (ETC)           2789
#
#       tasa_matriculaci_n_5_16  cobertura_neta  ...  reprobaci_n  \
# 0                       62.62           62.62  ...         6.55
# 1                       53.27           53.27  ...         6.78
# 2                       32.52           32.52  ...         9.47
# 3                       59.57           59.57  ...         5.34
# 4                       51.30           51.30  ...         9.24
# ...                       ...             ...  ...          ...
# 9995                    84.43           84.43  ...         7.54
# 9996                   118.64          118.64  ...         6.70
# 9997                    89.62           89.62  ...         0.10
# 9998                    76.49           76.49  ...         0.00
# 9999                    92.43           92.43  ...         9.41
#
#       reprobaci_n_transici_n  reprobaci_n_primaria  reprobaci_n_secundaria  \
# 0                       0.00                  1.96                   16.51
# 1                       0.00                  7.11                    9.39
# 2                       3.33                  6.93                   14.13
# 3                       0.57                  4.04                    8.33
# 4                       0.00                  7.32                   15.28
# ...                      ...                   ...                     ...
# 9995                    0.00                  5.92                   12.38
# 9996                    0.00                  6.31                    8.82
# 9997                    0.00                  0.03                    0.14
# 9998                    0.00                  0.00                    0.00
# 9999                    0.63                  7.56                   14.61
#
#       reprobaci_n_media  repitencia  repitencia_transici_n  \
# 0                  2.04        9.52                   0.00
# 1                  1.75        9.34                   6.95
# 2                  7.81        8.65                   6.67
# 3                  4.60       16.18                   7.75
# 4                  7.27        9.24                   2.86
# ...                 ...         ...                    ...
# 9995               3.54        6.08                   0.29
# 9996               7.51         NaN                   0.42
# 9997               0.67         NaN                    NaN
# 9998               0.00        7.66                   0.00
# 9999               3.95        5.91                   3.80
#
#       repitencia_primaria  repitencia_secundaria  repitencia_media
# 0                   10.46                  13.76              2.04
# 1                   11.84                   8.48              3.16
# 2                    9.04                  10.25              1.54
# 3                   21.04                  13.84              7.18
# 4                    7.62                  14.85              3.64
# ...                   ...                    ...               ...
# 9995                 5.30                   8.82              4.10
# 9996                  NaN                    NaN              2.37
# 9997                  NaN                    NaN              2.47
# 9998                  NaN                   9.73              4.84
# 9999                 6.29                   7.02              2.26
#
# [10000 rows x 41 columns]

# %%
df_secop_pd.to_csv('df_secop.csv')
df_men_pd.to_csv('df_men.csv')
